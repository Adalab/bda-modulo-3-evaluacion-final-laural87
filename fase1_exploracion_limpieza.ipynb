# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import chi2_contingency, ttest_ind

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Fase 1: Exploración y Limpieza
#
#  ## 1. Exploración Inicial:
#  Realiza una exploración inicial de los datos para identificar posibles problemas, como valores nulos, atípicos o datos faltantes en las columnas
#  relevantes.
#  Utiliza funciones de Pandas para obtener información sobre la estructura de los datos, la presencia de valores nulos y estadísticas básicas de
#  las columnas involucradas.
#  Une los dos conjuntos de datos de la forma más eficiente.

# %%
# Cargamos data Frame
df1 = pd.read_csv("data/Customer Flight Activity.csv",sep = ",")
df2 = pd.read_csv("data/Customer Loyalty History.csv",sep = ",")

# %% [markdown]
# # Comenzamos por el primer archivo

# %%
# Miramos la cabecera con las 3 primeras filas
df1.head(3)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0

# %%
# Miramos las 3 últimas filas

df1.tail(3)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 405621                            0
# 405622                            0
# 405623                            0

# %%
# Miramos 3 filas  aleatorias 

df1.sample(3)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 207782          366687  2018      1              10                        0
# 235590          945974  2018      2               0                        0
# 70565           259342  2017      5               2                        2
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 207782             10      2310               231.0                0
# 235590              0         0                 0.0                0
# 70565               4      1240               124.0                0
#
#         Dollar Cost Points Redeemed
# 207782                            0
# 235590                            0
# 70565                             0

# %%
#Creamos una función para entender el data frame


def entender_datos(df):
    
    # Encabezado
    print("INFO SOBRE NUESTROS DATOS")
    print("============================================================================")
    
    # Información general
    print(f"El número de filas es: {df.shape[0]}")
    print(f"El número de columnas es: {df.shape[1]}")
    print("============================================================================")
    
    # Descripción del DataFrame
    print("DESCRIPCIÓN ESTADÍSTICA")
    print(df.describe().T)
    print("============================================================================")
    
    # Columnas del DataFrame
    print("COLUMNAS")
    print(df.columns)
    print("============================================================================")
    
    # Filas duplicadas
    print(f"Número de filas duplicadas: {df.duplicated().sum()}")
    print("============================================================================")
    
    # Valores nulos totales
    print(f"Total de valores nulos: {df.isna().sum().sum()}")
    print("============================================================================")
    
    # Valores nulos por columna
    print("VALORES NULOS POR COLUMNA")
    print(df.isna().sum())
    print("============================================================================")

    #Porcentaje de valores nulos por columna
    print("PORCENTAJE NULOS POR COLUMNA")
    print(round(df.isna().sum() / df.shape[0] * 100,2))
    print("============================================================================")

    # Tipos de datos
    print("TIPOS DE DATOS")
    print(df.dtypes.value_counts())
    print("============================================================================")
    
    # Información del DataFrame
    print("INFORMACIÓN DETALLADA")
    df.info()
    print("============================================================================")

# %%
# Llamamos a la funcion para nuestro primer DataFrame

entender_datos(df1)
# Out:
# INFO SOBRE NUESTROS DATOS
# ============================================================================
# El número de filas es: 405624
# El número de columnas es: 10
# ============================================================================
# DESCRIPCIÓN ESTADÍSTICA
#                                 count           mean            std       min  \
# Loyalty Number               405624.0  550037.873084  258935.286969  100018.0
# Year                         405624.0    2017.500000       0.500001    2017.0
# Month                        405624.0       6.500000       3.452057       1.0
# Flights Booked               405624.0       4.115052       5.225518       0.0
# Flights with Companions      405624.0       1.031805       2.076869       0.0
# Total Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points Accumulated           405624.0     123.692721     146.599831       0.0
# Points Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar Cost Points Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                    25%       50%        75%       max
# Loyalty Number               326961.00  550834.0  772194.00  999986.0
# Year                           2017.00    2017.5    2018.00    2018.0
# Month                             3.75       6.5       9.25      12.0
# Flights Booked                    0.00       1.0       8.00      21.0
# Flights with Companions           0.00       0.0       1.00      11.0
# Total Flights                     0.00       1.0      10.00      32.0
# Distance                          0.00     488.0    2336.00    6293.0
# Points Accumulated                0.00      50.0     239.00     676.5
# Points Redeemed                   0.00       0.0       0.00     876.0
# Dollar Cost Points Redeemed       0.00       0.0       0.00      71.0
# ============================================================================
# COLUMNAS
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')
# ============================================================================
# Número de filas duplicadas: 1864
# ============================================================================
# Total de valores nulos: 0
# ============================================================================
# VALORES NULOS POR COLUMNA
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64
# ============================================================================
# PORCENTAJE NULOS POR COLUMNA
# Loyalty Number                 0.0
# Year                           0.0
# Month                          0.0
# Flights Booked                 0.0
# Flights with Companions        0.0
# Total Flights                  0.0
# Distance                       0.0
# Points Accumulated             0.0
# Points Redeemed                0.0
# Dollar Cost Points Redeemed    0.0
# dtype: float64
# ============================================================================
# TIPOS DE DATOS
# int64      9
# float64    1
# Name: count, dtype: int64
# ============================================================================
# INFORMACIÓN DETALLADA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB
# ============================================================================

# %% [markdown]
# ### Compruebo el segundo archivo

# %%
# miramos las 3 primeras columnas
df2.head(3)
# Out:
#    Loyalty Number Country          Province       City Postal Code  Gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
#
#   Education   Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  Bachelor  83236.0        Married         Star  3839.14        Standard
# 1   College      NaN       Divorced         Star  3839.61        Standard
# 2   College      NaN         Single         Star  3839.75        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN
# 2             2014                 7             2018.0                 1.0

# %%
# miramos las 3 últimas filas
df2.tail(3)
# Out:
#        Loyalty Number Country          Province        City Postal Code  \
# 16734          776187  Canada  British Columbia   Vancouver     V5R 1W3
# 16735          906428  Canada             Yukon  Whitehorse     Y2K 6R0
# 16736          652627  Canada          Manitoba    Winnipeg     R2C 0M5
#
#        Gender Education   Salary Marital Status Loyalty Card       CLV  \
# 16734    Male   College      NaN         Single         Star  74228.52
# 16735    Male  Bachelor -57297.0        Married         Star  10018.66
# 16736  Female  Bachelor  75049.0        Married         Star  83325.38
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 16734        Standard             2014                 3                NaN
# 16735  2018 Promotion             2018                 4                NaN
# 16736        Standard             2015                12             2016.0
#
#        Cancellation Month
# 16734                 NaN
# 16735                 NaN
# 16736                 8.0

# %%
# miramos 3 filas aleatorias
df2.sample(3)
# Out:
#        Loyalty Number Country          Province          City Postal Code  \
# 4408           712521  Canada           Ontario        Ottawa     K1F 2R2
# 13317          556313  Canada  British Columbia  Dawson Creek     U5I 4F1
# 16256          318595  Canada     New Brunswick   Fredericton     E3B 2H2
#
#       Gender Education   Salary Marital Status Loyalty Card       CLV  \
# 4408    Male  Bachelor  78245.0       Divorced         Nova   2849.25
# 13317   Male  Bachelor  76602.0         Single         Star   5049.69
# 16256   Male  Bachelor  97472.0        Married         Star  17019.01
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 4408         Standard             2015                 9                NaN
# 13317        Standard             2013                 7                NaN
# 16256        Standard             2018                 5                NaN
#
#        Cancellation Month
# 4408                  NaN
# 13317                 NaN
# 16256                 NaN

# %% [markdown]
# Compruebo el segundo archivo

# %%
#llamamos a la funciçon que hemos creado antes para entender los datos

entender_datos(df2)
# Out:
# INFO SOBRE NUESTROS DATOS
# ============================================================================
# El número de filas es: 16737
# El número de columnas es: 16
# ============================================================================
# DESCRIPCIÓN ESTADÍSTICA
#                       count           mean            std        min  \
# Loyalty Number      16737.0  549735.880445  258912.132453  100018.00
# Salary              12499.0   79245.609409   35008.297285  -58486.00
# CLV                 16737.0    7988.896536    6860.982280    1898.01
# Enrollment Year     16737.0    2015.253211       1.979111    2012.00
# Enrollment Month    16737.0       6.669116       3.398958       1.00
# Cancellation Year    2067.0    2016.503145       1.380743    2013.00
# Cancellation Month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# Loyalty Number      326603.00  550434.00  772019.00  999986.00
# Salary               59246.50   73455.00   88517.50  407228.00
# CLV                   3980.84    5780.18    8940.58   83325.38
# Enrollment Year       2014.00    2015.00    2017.00    2018.00
# Enrollment Month         4.00       7.00      10.00      12.00
# Cancellation Year     2016.00    2017.00    2018.00    2018.00
# Cancellation Month       4.00       7.00      10.00      12.00
# ============================================================================
# COLUMNAS
# Index(['Loyalty Number', 'Country', 'Province', 'City', 'Postal Code',
#        'Gender', 'Education', 'Salary', 'Marital Status', 'Loyalty Card',
#        'CLV', 'Enrollment Type', 'Enrollment Year', 'Enrollment Month',
#        'Cancellation Year', 'Cancellation Month'],
#       dtype='object')
# ============================================================================
# Número de filas duplicadas: 0
# ============================================================================
# Total de valores nulos: 33578
# ============================================================================
# VALORES NULOS POR COLUMNA
# Loyalty Number            0
# Country                   0
# Province                  0
# City                      0
# Postal Code               0
# Gender                    0
# Education                 0
# Salary                 4238
# Marital Status            0
# Loyalty Card              0
# CLV                       0
# Enrollment Type           0
# Enrollment Year           0
# Enrollment Month          0
# Cancellation Year     14670
# Cancellation Month    14670
# dtype: int64
# ============================================================================
# PORCENTAJE NULOS POR COLUMNA
# Loyalty Number         0.00
# Country                0.00
# Province               0.00
# City                   0.00
# Postal Code            0.00
# Gender                 0.00
# Education              0.00
# Salary                25.32
# Marital Status         0.00
# Loyalty Card           0.00
# CLV                    0.00
# Enrollment Type        0.00
# Enrollment Year        0.00
# Enrollment Month       0.00
# Cancellation Year     87.65
# Cancellation Month    87.65
# dtype: float64
# ============================================================================
# TIPOS DE DATOS
# object     9
# float64    4
# int64      3
# Name: count, dtype: int64
# ============================================================================
# INFORMACIÓN DETALLADA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
#  15  Cancellation Month  2067 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 2.0+ MB
# ============================================================================

# %% [markdown]
# He comprobado que en el segundo archivo hay columnas del tipo objeto
# Miramos las columnas ´únicas de el tipo object'

# %%
#Creo un data frame con las columnas tipo objeto 

df2_cat = df2.select_dtypes(include = "object")


# creamos una variable con los nombres de las columnas del DataFrame de las variables categóricas utilizando el método '.columns'
columnas_cat = df2_cat.columns
print(f"Las columnas del DataFrame de variables categóricas son {columnas_cat}")

# empezamos a iterar por cada una de las columnas para sacar sus valores únicos y sus frecuencias
for columna in columnas_cat:
    print(f" \n----------- ESTAMOS ANALIZANDO LA COLUMNA: '{columna.upper()}' -----------\n")
    print(f"Sus valores únicos son: {df2_cat[columna].unique()}\n")
    print(f"Las frecuencias de los valores únicos de las categorías son: {df2_cat[columna].value_counts()} ")
# Out:
# Las columnas del DataFrame de variables categóricas son Index(['Country', 'Province', 'City', 'Postal Code', 'Gender', 'Education',
#        'Marital Status', 'Loyalty Card', 'Enrollment Type'],
#       dtype='object')
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'COUNTRY' -----------
#
# Sus valores únicos son: ['Canada']
#
# Las frecuencias de los valores únicos de las categorías son: Country
# Canada    16737
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'PROVINCE' -----------
#
# Sus valores únicos son: ['Ontario' 'Alberta' 'British Columbia' 'Quebec' 'Yukon' 'New Brunswick'
#  'Manitoba' 'Nova Scotia' 'Saskatchewan' 'Newfoundland'
#  'Prince Edward Island']
#
# Las frecuencias de los valores únicos de las categorías son: Province
# Ontario                 5404
# British Columbia        4409
# Quebec                  3300
# Alberta                  969
# Manitoba                 658
# New Brunswick            636
# Nova Scotia              518
# Saskatchewan             409
# Newfoundland             258
# Yukon                    110
# Prince Edward Island      66
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'CITY' -----------
#
# Sus valores únicos son: ['Toronto' 'Edmonton' 'Vancouver' 'Hull' 'Whitehorse' 'Trenton' 'Montreal'
#  'Dawson Creek' 'Quebec City' 'Fredericton' 'Ottawa' 'Tremblant' 'Calgary'
#  'Thunder Bay' 'Whistler' 'Peace River' 'Winnipeg' 'Sudbury'
#  'West Vancouver' 'Halifax' 'London' 'Regina' 'Kelowna' "St. John's"
#  'Victoria' 'Kingston' 'Banff' 'Moncton' 'Charlottetown']
#
# Las frecuencias de los valores únicos de las categorías son: City
# Toronto           3351
# Vancouver         2582
# Montreal          2059
# Winnipeg           658
# Whistler           582
# Halifax            518
# Ottawa             509
# Trenton            486
# Edmonton           486
# Quebec City        485
# Dawson Creek       444
# Fredericton        425
# Regina             409
# Kingston           401
# Tremblant          398
# Victoria           389
# Hull               358
# West Vancouver     324
# St. John's         258
# Thunder Bay        256
# Sudbury            227
# Moncton            211
# Calgary            191
# Banff              179
# London             174
# Peace River        113
# Whitehorse         110
# Kelowna             88
# Charlottetown       66
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'POSTAL CODE' -----------
#
# Sus valores únicos son: ['M2Z 4K1' 'T3G 6Y6' 'V6E 3D9' 'P1W 1K4' 'J8Y 3Z5' 'Y2K 6R0' 'P5S 6R4'
#  'K8V 4B2' 'H2Y 2W2' 'M8Y 4K8' 'U5I 4F1' 'G1B 3L5' 'H4G 3T4' 'M2M 7K8'
#  'M2M 6J7' 'E3B 2H2' 'M1R 4K3' 'T9G 1W3' 'H2Y 4R4' 'V5R 1W3' 'P1L 8X8'
#  'K1F 2R2' 'H5Y 2S9' 'V1E 4R6' 'H2T 2J6' 'T3E 2V9' 'H2T 9K8' 'K8T 5M5'
#  'V6T 1Y8' 'P2T 6G3' 'T9O 2W2' 'V6E 3Z3' 'R6Y 4T5' 'M5V 1G5' 'V6V 8Z3'
#  'B3J 9S2' 'M5B 3E4' 'R2C 0M5' 'S6J 3G0' 'M2P 4F6' 'P1J 8T7' 'V09 2E9'
#  'A1C 6H9' 'V10 6T5' 'B3C 2M8' 'M9K 2P4' 'T4V 1D4' 'R3R 3T4' 'S1J 3C5'
#  'E1A 2A7' 'K1G 4Z0' 'H3T 8L4' 'C1A 6E8' 'H3J 5I6' 'M3R 4K8']
#
# Las frecuencias de los valores únicos de las categorías son: Postal Code
# V6E 3D9    911
# V5R 1W3    684
# V6T 1Y8    582
# V6E 3Z3    544
# M2M 7K8    534
# P1J 8T7    500
# H2T 9K8    499
# K8V 4B2    486
# G1B 3L5    485
# H2T 2J6    446
# U5I 4F1    444
# V1E 4R6    443
# E3B 2H2    425
# R2C 0M5    415
# M9K 2P4    401
# H5Y 2S9    398
# V10 6T5    389
# K1F 2R2    389
# H2Y 2W2    365
# J8Y 3Z5    358
# M8Y 4K8    340
# H4G 3T4    338
# B3J 9S2    329
# V6V 8Z3    324
# P2T 6G3    322
# H2Y 4R4    315
# M1R 4K3    313
# P1L 8X8    282
# P1W 1K4    275
# T9G 1W3    266
# A1C 6H9    258
# M2Z 4K1    257
# K8T 5M5    256
# P5S 6R4    246
# M5V 1G5    227
# S6J 3G0    226
# T3G 6Y6    220
# E1A 2A7    211
# T3E 2V9    191
# B3C 2M8    189
# S1J 3C5    183
# T4V 1D4    179
# M5B 3E4    174
# M2M 6J7    153
# R6Y 4T5    143
# M2P 4F6    126
# K1G 4Z0    120
# T9O 2W2    113
# Y2K 6R0    110
# R3R 3T4    100
# H3T 8L4     89
# V09 2E9     88
# C1A 6E8     66
# H3J 5I6      7
# M3R 4K8      3
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'GENDER' -----------
#
# Sus valores únicos son: ['Female' 'Male']
#
# Las frecuencias de los valores únicos de las categorías son: Gender
# Female    8410
# Male      8327
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'EDUCATION' -----------
#
# Sus valores únicos son: ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
#
# Las frecuencias de los valores únicos de las categorías son: Education
# Bachelor                10475
# College                  4238
# High School or Below      782
# Doctor                    734
# Master                    508
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'MARITAL STATUS' -----------
#
# Sus valores únicos son: ['Married' 'Divorced' 'Single']
#
# Las frecuencias de los valores únicos de las categorías son: Marital Status
# Married     9735
# Single      4484
# Divorced    2518
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'LOYALTY CARD' -----------
#
# Sus valores únicos son: ['Star' 'Aurora' 'Nova']
#
# Las frecuencias de los valores únicos de las categorías son: Loyalty Card
# Star      7637
# Nova      5671
# Aurora    3429
# Name: count, dtype: int64
#
# ----------- ESTAMOS ANALIZANDO LA COLUMNA: 'ENROLLMENT TYPE' -----------
#
# Sus valores únicos son: ['Standard' '2018 Promotion']
#
# Las frecuencias de los valores únicos de las categorías son: Enrollment Type
# Standard          15766
# 2018 Promotion      971
# Name: count, dtype: int64

# %%
df1.head(1)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0

# %%
df2.head(1)
# Out:
#    Loyalty Number Country Province     City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
#
#     Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  83236.0        Married         Star  3839.14        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN

# %% [markdown]
# ### Unimos los dos Dataframe
#
# En este caso vamos a elegir el metodo JOIN.  Se utiliza para combinar los datos de dos DataFrames en función de los índices de las filas. Proporciona una forma conveniente de realizar uniones basadas en índices en lugar de columnas.

# %%
#compruebo de nuevo las filas y columnas que tiene nuestro data frame

print(f'Las filas y columnas de df1 son: {df1.shape}')
print(f'Las filas y columnas de df2 son: {df2.shape}')
# Out:
# Las filas y columnas de df1 son: (405624, 10)
# Las filas y columnas de df2 son: (16737, 16)

# %%
# utilizamos el método 'set_index()' para poner la columna de 'ID' como índice de nuestro DataFrame
df2.set_index(["Loyalty Number"], inplace = True)

# vemos como ha quedado el DataFrame
df2.head(1)
# Out:
#                Country Province     City Postal Code  Gender Education  \
# Loyalty Number
# 480934          Canada  Ontario  Toronto     M2Z 4K1  Female  Bachelor
#
#                  Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# Loyalty Number
# 480934          83236.0        Married         Star  3839.14        Standard
#
#                 Enrollment Year  Enrollment Month  Cancellation Year  \
# Loyalty Number
# 480934                     2016                 2                NaN
#
#                 Cancellation Month
# Loyalty Number
# 480934                         NaN

# %%
# en este punto el orden es importante, y tendremos pasar primero el DataFrame que no tiene en el índice la columna y dentro del paréntesis el DataFrame que tiene la columna común en el índice. 
df_join = df1.join(df2, on = "Loyalty Number")
df_join.sample() #recuerden que sample es solo para traernos una muestra del dataframe
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 161195          583252  2017     10               8                        4
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 161195             12      1056               105.0                0
#
#         Dollar Cost Points Redeemed Country Province     City Postal Code  \
# 161195                            0  Canada  Ontario  Toronto     M2Z 4K1
#
#        Gender Education   Salary Marital Status Loyalty Card      CLV  \
# 161195   Male    Master  94231.0        Married         Nova  3700.39
#
#        Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 161195        Standard             2017                 4                NaN
#
#         Cancellation Month
# 161195                 NaN

# %%
print(f'Las filas y columnas de df1 son: {df_join.shape}')
# Out:
# Las filas y columnas de df1 son: (405624, 25)

# %%
entender_datos(df_join)
# Out:
# INFO SOBRE NUESTROS DATOS
# ============================================================================
# El número de filas es: 405624
# El número de columnas es: 25
# ============================================================================
# DESCRIPCIÓN ESTADÍSTICA
#                                 count           mean            std  \
# Loyalty Number               405624.0  550037.873084  258935.286969
# Year                         405624.0    2017.500000       0.500001
# Month                        405624.0       6.500000       3.452057
# Flights Booked               405624.0       4.115052       5.225518
# Flights with Companions      405624.0       1.031805       2.076869
# Total Flights                405624.0       5.146858       6.521227
# Distance                     405624.0    1208.880059    1433.155320
# Points Accumulated           405624.0     123.692721     146.599831
# Points Redeemed              405624.0      30.696872     125.486049
# Dollar Cost Points Redeemed  405624.0       2.484503      10.150038
# Salary                       302952.0   79268.825953   34992.133508
# CLV                          405624.0    7991.976226    6863.663857
# Enrollment Year              405624.0    2015.252529       1.979427
# Enrollment Month             405624.0       6.668008       3.399766
# Cancellation Year             50064.0    2016.499521       1.384336
# Cancellation Month            50064.0       6.966443       3.448300
#
#                                    min        25%        50%        75%  \
# Loyalty Number               100018.00  326961.00  550834.00  772194.00
# Year                           2017.00    2017.00    2017.50    2018.00
# Month                             1.00       3.75       6.50       9.25
# Flights Booked                    0.00       0.00       1.00       8.00
# Flights with Companions           0.00       0.00       0.00       1.00
# Total Flights                     0.00       0.00       1.00      10.00
# Distance                          0.00       0.00     488.00    2336.00
# Points Accumulated                0.00       0.00      50.00     239.00
# Points Redeemed                   0.00       0.00       0.00       0.00
# Dollar Cost Points Redeemed       0.00       0.00       0.00       0.00
# Salary                       -58486.00   59262.00   73479.00   88612.00
# CLV                            1898.01    3985.32    5776.34    8936.82
# Enrollment Year                2012.00    2014.00    2015.00    2017.00
# Enrollment Month                  1.00       4.00       7.00      10.00
# Cancellation Year              2013.00    2016.00    2017.00    2018.00
# Cancellation Month                1.00       4.00       7.00      10.00
#
#                                    max
# Loyalty Number               999986.00
# Year                           2018.00
# Month                            12.00
# Flights Booked                   21.00
# Flights with Companions          11.00
# Total Flights                    32.00
# Distance                       6293.00
# Points Accumulated              676.50
# Points Redeemed                 876.00
# Dollar Cost Points Redeemed      71.00
# Salary                       407228.00
# CLV                           83325.38
# Enrollment Year                2018.00
# Enrollment Month                 12.00
# Cancellation Year              2018.00
# Cancellation Month               12.00
# ============================================================================
# COLUMNAS
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed',
#        'Country', 'Province', 'City', 'Postal Code', 'Gender', 'Education',
#        'Salary', 'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type',
#        'Enrollment Year', 'Enrollment Month', 'Cancellation Year',
#        'Cancellation Month'],
#       dtype='object')
# ============================================================================
# Número de filas duplicadas: 1864
# ============================================================================
# Total de valores nulos: 813792
# ============================================================================
# VALORES NULOS POR COLUMNA
# Loyalty Number                      0
# Year                                0
# Month                               0
# Flights Booked                      0
# Flights with Companions             0
# Total Flights                       0
# Distance                            0
# Points Accumulated                  0
# Points Redeemed                     0
# Dollar Cost Points Redeemed         0
# Country                             0
# Province                            0
# City                                0
# Postal Code                         0
# Gender                              0
# Education                           0
# Salary                         102672
# Marital Status                      0
# Loyalty Card                        0
# CLV                                 0
# Enrollment Type                     0
# Enrollment Year                     0
# Enrollment Month                    0
# Cancellation Year              355560
# Cancellation Month             355560
# dtype: int64
# ============================================================================
# PORCENTAJE NULOS POR COLUMNA
# Loyalty Number                  0.00
# Year                            0.00
# Month                           0.00
# Flights Booked                  0.00
# Flights with Companions         0.00
# Total Flights                   0.00
# Distance                        0.00
# Points Accumulated              0.00
# Points Redeemed                 0.00
# Dollar Cost Points Redeemed     0.00
# Country                         0.00
# Province                        0.00
# City                            0.00
# Postal Code                     0.00
# Gender                          0.00
# Education                       0.00
# Salary                         25.31
# Marital Status                  0.00
# Loyalty Card                    0.00
# CLV                             0.00
# Enrollment Type                 0.00
# Enrollment Year                 0.00
# Enrollment Month                0.00
# Cancellation Year              87.66
# Cancellation Month             87.66
# dtype: float64
# ============================================================================
# TIPOS DE DATOS
# int64      11
# object      9
# float64     5
# Name: count, dtype: int64
# ============================================================================
# INFORMACIÓN DETALLADA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
#  10  Country                      405624 non-null  object
#  11  Province                     405624 non-null  object
#  12  City                         405624 non-null  object
#  13  Postal Code                  405624 non-null  object
#  14  Gender                       405624 non-null  object
#  15  Education                    405624 non-null  object
#  16  Salary                       302952 non-null  float64
#  17  Marital Status               405624 non-null  object
#  18  Loyalty Card                 405624 non-null  object
#  19  CLV                          405624 non-null  float64
#  20  Enrollment Type              405624 non-null  object
#  21  Enrollment Year              405624 non-null  int64
#  22  Enrollment Month             405624 non-null  int64
#  23  Cancellation Year            50064 non-null   float64
#  24  Cancellation Month           50064 non-null   float64
# dtypes: float64(5), int64(11), object(9)
# memory usage: 77.4+ MB
# ============================================================================

# %%
# Creamos un CSV con los datos unidos para copia de seguridad

df_join.to_csv('data/data_join.csv')

# %% [markdown]
#  ## 2. Limpieza de Datos:
#  Elimina o trata los valores nulos, si los hay, en las columnas clave para asegurar que los datos estén completos.
#  Verifica la consistencia y corrección de los datos para asegurarte de que los datos se presenten de forma coherente.
#  Realiza cualquier ajuste o conversión necesaria en las columnas (por ejemplo, cambiar tipos de datos) para garantizar la adecuación de los
#  datos para el análisis estadístico

# %%
# Leo el csv con los datos unidos
df = pd.read_csv('data/data_join.csv')

# %%
# compruebo la columa Loyality Number para ver si tiene duplicados

print(f'El numero de duplidados de este data frame es {df["Loyalty Number"].duplicated().sum()}') 
 

# Compruebo un valor aleatorio de esta columna

df[df["Loyalty Number"] == 100018].head(6)
# Out:
# El numero de duplidados de este data frame es 388887
#        Unnamed: 0  Loyalty Number  Year  Month  Flights Booked  \
# 0               0          100018  2017      1               3
# 16901       16901          100018  2017      2               2
# 46353       46353          100018  2018     10               6
# 50703       50703          100018  2017      4               4
# 67604       67604          100018  2017      5               0
# 84505       84505          100018  2017      6               4
#
#        Flights with Companions  Total Flights  Distance  Points Accumulated  \
# 0                            0              3      1521               152.0
# 16901                        2              4      1320               132.0
# 46353                        4             10      3110               311.0
# 50703                        0              4       924                92.0
# 67604                        0              0         0                 0.0
# 84505                        1              5      4330               433.0
#
#        Points Redeemed  Dollar Cost Points Redeemed Country Province  \
# 0                    0                            0  Canada  Alberta
# 16901                0                            0  Canada  Alberta
# 46353              385                           31  Canada  Alberta
# 50703                0                            0  Canada  Alberta
# 67604                0                            0  Canada  Alberta
# 84505                0                            0  Canada  Alberta
#
#            City Postal Code  Gender Education   Salary Marital Status  \
# 0      Edmonton     T9G 1W3  Female  Bachelor  92552.0        Married
# 16901  Edmonton     T9G 1W3  Female  Bachelor  92552.0        Married
# 46353  Edmonton     T9G 1W3  Female  Bachelor  92552.0        Married
# 50703  Edmonton     T9G 1W3  Female  Bachelor  92552.0        Married
# 67604  Edmonton     T9G 1W3  Female  Bachelor  92552.0        Married
# 84505  Edmonton     T9G 1W3  Female  Bachelor  92552.0        Married
#
#       Loyalty Card     CLV Enrollment Type  Enrollment Year  Enrollment Month  \
# 0           Aurora  7919.2        Standard             2016                 8
# 16901       Aurora  7919.2        Standard             2016                 8
# 46353       Aurora  7919.2        Standard             2016                 8
# 50703       Aurora  7919.2        Standard             2016                 8
# 67604       Aurora  7919.2        Standard             2016                 8
# 84505       Aurora  7919.2        Standard             2016                 8
#
#        Cancellation Year  Cancellation Month
# 0                    NaN                 NaN
# 16901                NaN                 NaN
# 46353                NaN                 NaN
# 50703                NaN                 NaN
# 67604                NaN                 NaN
# 84505                NaN                 NaN

# %%
# Veo que la información es un historíco por mes y año de los vuelos tomados. Por lo tanto no tendría sentido tener duplicados

df.drop_duplicates(inplace=True)

#comprobamos que no tenemos duplicados
df.duplicated().sum()
# Out:
# 0

# %%
# Borramos la columna Unamed que se creó al unir los dos archivos y la columna contry porque únicamente salen datos de este país.

columnas_borrar = ['Unnamed: 0','Country']

def borrar_columnas (datos, columnas):
    datos.drop( columns = columnas, inplace= True)

borrar_columnas(df,columnas_borrar)

# %%
#Compruebo que se ha borrado las columnas

df.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed',
#        'Province', 'City', 'Postal Code', 'Gender', 'Education', 'Salary',
#        'Marital Status', 'Loyalty Card', 'CLV', 'Enrollment Type',
#        'Enrollment Year', 'Enrollment Month', 'Cancellation Year',
#        'Cancellation Month'],
#       dtype='object')

# %%
df.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed          Province          City Postal Code  \
# 0                            0           Alberta      Edmonton     T9G 1W3
# 1                            0           Ontario       Toronto     M1R 4K3
# 2                            0  British Columbia  Dawson Creek     U5I 4F1
# 3                            0  British Columbia     Vancouver     V5R 1W3
# 4                            0           Ontario       Toronto     P1L 8X8
#
#    Gender Education   Salary Marital Status Loyalty Card      CLV  \
# 0  Female  Bachelor  92552.0        Married       Aurora  7919.20
# 1    Male   College      NaN         Single         Nova  2887.74
# 2  Female   College      NaN       Divorced         Nova  2838.07
# 3    Male  Bachelor  63253.0        Married         Star  4170.57
# 4  Female  Bachelor  91163.0       Divorced         Star  6622.05
#
#   Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 0        Standard             2016                 8                NaN
# 1        Standard             2013                 3                NaN
# 2        Standard             2016                 7                NaN
# 3        Standard             2015                 8                NaN
# 4        Standard             2014                 1                NaN
#
#    Cancellation Month
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# Vamos a unificar el formato de las columnas, las queremos en minúscula y que el espacio sea una barra baja

# %%
#hacemos una variable de nuevas columnas que hará que las columnas aparezcan en miinuscula y que remplace el espacio por comas
new_columns = {column : column.lower().replace(' ', '_') for column in df}


#renombramos las columnas antiguas por las nuevas
df.rename(columns = new_columns, inplace= True)


# comprobamos que se ha realizado
df.sample(10)
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 248967          755145  2018      3               0                        0
# 380741          575147  2018     11               0                        0
# 118230          995943  2017      7               0                        0
# 313207          792412  2017      1              11                        0
# 33640           991056  2017      2               0                        0
# 36550           248011  2017      3               0                        0
# 237205          684371  2018      2               7                        0
# 92715           538042  2017      6               0                        0
# 290530          272686  2018      6               0                        0
# 164812          773397  2017     10               0                        0
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 248967              0         0                0.00                0
# 380741              0         0                0.00                0
# 118230              0         0                0.00                0
# 313207             11      2332              233.00                0
# 33640               0         0                0.00                0
# 36550               0         0                0.00                0
# 237205              7      1330              166.25                0
# 92715               0         0                0.00                0
# 290530              0         0                0.00                0
# 164812              0         0                0.00                0
#
#         dollar_cost_points_redeemed          province            city  \
# 248967                            0  British Columbia       Vancouver
# 380741                            0           Alberta        Edmonton
# 118230                            0  British Columbia  West Vancouver
# 313207                            0  British Columbia       Vancouver
# 33640                             0       Nova Scotia         Halifax
# 36550                             0           Ontario         Toronto
# 237205                            0           Ontario        Kingston
# 92715                             0  British Columbia       Vancouver
# 290530                            0      Saskatchewan          Regina
# 164812                            0           Alberta         Calgary
#
#        postal_code  gender             education    salary marital_status  \
# 248967     V5R 1W3  Female              Bachelor  104928.0         Single
# 380741     T9G 1W3  Female              Bachelor   96926.0         Single
# 118230     V6V 8Z3    Male              Bachelor   58209.0       Divorced
# 313207     V5R 1W3    Male                Doctor   86182.0        Married
# 33640      B3J 9S2  Female               College       NaN         Single
# 36550      P1L 8X8    Male               College       NaN        Married
# 237205     M9K 2P4    Male               College       NaN         Single
# 92715      V6E 3D9  Female  High School or Below   45384.0        Married
# 290530     S6J 3G0    Male              Bachelor   94805.0        Married
# 164812     T3E 2V9    Male              Bachelor   57150.0         Single
#
#        loyalty_card       clv enrollment_type  enrollment_year  \
# 248967       Aurora  17786.28        Standard             2018
# 380741         Star  14042.10        Standard             2012
# 118230         Star   4139.90        Standard             2012
# 313207         Star   5384.67        Standard             2016
# 33640          Star   2710.92        Standard             2017
# 36550          Nova   4068.09        Standard             2016
# 237205         Nova  10175.24        Standard             2015
# 92715          Nova   4726.87        Standard             2015
# 290530       Aurora   5846.11        Standard             2018
# 164812         Star   6369.26        Standard             2013
#
#         enrollment_month  cancellation_year  cancellation_month
# 248967                10                NaN                 NaN
# 380741                 8                NaN                 NaN
# 118230                 7                NaN                 NaN
# 313207                 8             2017.0                 4.0
# 33640                  6                NaN                 NaN
# 36550                  6                NaN                 NaN
# 237205                 2                NaN                 NaN
# 92715                 12                NaN                 NaN
# 290530                12                NaN                 NaN
# 164812                 5                NaN                 NaN

# %%
# Creamos una función para convertir en lower (minúscula) y le quitamos los espacios de delante y detrás 


def modificar_lower_strip (lista_columnas):
    for columna in columnas_ojeto:
        df[columna] = df[columna].str.strip().str.lower()


# llamamos a la función y seleccionamos las columnas de tipo objeto
columnas_ojeto = df.select_dtypes(include = "object").columns
modificar_lower_strip(columnas_ojeto)

# %% [markdown]
# Vemos a comprobar los nulos

# %%
listacolumnas = ['salary', 'cancellation_year', 'cancellation_month']
for columna in listacolumnas:
    print(f'El porcentaje de nulos del la columna {columna} es {round(df[columna].isna().sum() / df[columna].shape[0] * 100,2)}')
# Out:
# El porcentaje de nulos del la columna salary es 25.31
# El porcentaje de nulos del la columna cancellation_year es 87.66
# El porcentaje de nulos del la columna cancellation_month es 87.66

# %%
#Empezamos por la columna salary
print(f'El porcentaje de nulos del la columna salario es {round(df["salary"].isna().sum() / df["salary"].shape[0] * 100,2)}')

# Antes de solucionar los nulos la columna salary tiene valores negativos
df[df['salary'] <= 0].head(2)
# Out:
# El porcentaje de nulos del la columna salario es 25.31
#      loyalty_number  year  month  flights_booked  flights_with_companions  \
# 293          115505  2017      1               0                        0
# 961          152016  2017      1               0                        0
#
#      total_flights  distance  points_accumulated  points_redeemed  \
# 293              0         0                 0.0                0
# 961              0         0                 0.0                0
#
#      dollar_cost_points_redeemed      province        city postal_code  \
# 293                            0  newfoundland  st. john's     a1c 6h9
# 961                            0       ontario     toronto     p1j 8t7
#
#      gender education   salary marital_status loyalty_card      clv  \
# 293    male  bachelor -10605.0        married         nova  5860.17
# 961  female  bachelor -58486.0        married       aurora  5067.21
#
#     enrollment_type  enrollment_year  enrollment_month  cancellation_year  \
# 293  2018 promotion             2018                 4                NaN
# 961  2018 promotion             2018                 2                NaN
#
#      cancellation_month
# 293                 NaN
# 961                 NaN

# %%
# Cambiamos los valores negativos de salary a positivos
df['salary'] = df['salary'].abs()

#comprobamos  que no quede ningún negativo
df[df['salary'] <= 0].head(2)
# Out:
# Empty DataFrame
# Columns: [loyalty_number, year, month, flights_booked, flights_with_companions, total_flights, distance, points_accumulated, points_redeemed, dollar_cost_points_redeemed, province, city, postal_code, gender, education, salary, marital_status, loyalty_card, clv, enrollment_type, enrollment_year, enrollment_month, cancellation_year, cancellation_month]
# Index: []

# %% [markdown]
# Sabiendo que el orden de estudios de Canada es el siguiente
#
# Doctor
#
# Master
#
# Bachelor
#
# College
#
# High School or Below

# %%
df.groupby('education')['salary'].mean()
# Out:
# education
# bachelor                 72601.235033
# college                           NaN
# doctor                  178335.439516
# high school or below     61112.377525
# master                  103767.494163
# Name: salary, dtype: float64

# %%
# calculamos la media de los niveles de estudios más cercanos según el estudio que he realizado 

df_fil = df[(df['education'] == 'high school or below') | (df['education'] == 'bachelor') ]

df_fil['education'].unique()

df_fil['salary'].mean()
# Out:
# 71800.60369555654

# %%
# Vamos a imputar esta media los valores que tengasn colege en education --- df.loc sirve para seleccionar datos por etiquetas de filas y columnas df.loc[row_labels, column_labels]

df.loc[df['education'] == 'college', 'salary'] = round(df_fil['salary'].mean(),2)

# %%
# comprobamos
df[df['education'] == 'college'].tail(2)
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 405619          999902  2018     12               0                        0
# 405622          999982  2018     12               0                        0
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 405619              0         0                   0                0
# 405622              0         0                   0                0
#
#         dollar_cost_points_redeemed          province      city postal_code  \
# 405619                            0           ontario   toronto     m1r 4k3
# 405622                            0  british columbia  victoria     v10 6t5
#
#        gender education  salary marital_status loyalty_card      clv  \
# 405619   male   college   71800        married       aurora  7290.07
# 405622   male   college   71800        married         star  2631.56
#
#        enrollment_type  enrollment_year  enrollment_month  cancellation_year  \
# 405619        standard             2014                 5                  0
# 405622        standard             2018                 7                  0
#
#         cancellation_month
# 405619                   0
# 405622                   0

# %%
df.groupby('education')['salary'].mean()
# Out:
# education
# bachelor                 72601.235033
# college                  71800.600000
# doctor                  178335.439516
# high school or below     61112.377525
# master                  103767.494163
# Name: salary, dtype: float64

# %%
# Las dos columnas cancelacion tienen el mismo porcentaje de nulos. Creo que no debemos borrar esta información porque son personas que no han cancelado la suscripción por lo tanto cambiaré los valores Nan creando una categoria nueva con 'o' que querrá decir que no han cancelado
lista = ['cancellation_year', 'cancellation_month']
for columna in lista:

    df[columna].fillna(0, inplace=True)
    print(f'El porcentaje de nulos del la columna {columna} es {round(df[columna].isna().sum() / df[columna].shape[0] * 100,2)}')
# Out:
# El porcentaje de nulos del la columna cancellation_year es 0.0
# El porcentaje de nulos del la columna cancellation_month es 0.0

# %%
#creamos una función para convertir todas las columnas en int excepto la columna que se llama clv

# Definir la función de conversión
def convert_column_to_int(column):
    if column.name != 'clv' and column.dtype == 'float64':
        return column.astype('int64')
    return column

# Aplicar la función a cada columna
df = df.apply(convert_column_to_int)

# %%
df.dtypes
# Out:
# loyalty_number                   int64
# year                             int64
# month                            int64
# flights_booked                   int64
# flights_with_companions          int64
# total_flights                    int64
# distance                         int64
# points_accumulated               int64
# points_redeemed                  int64
# dollar_cost_points_redeemed      int64
# province                        object
# city                            object
# postal_code                     object
# gender                          object
# education                       object
# salary                           int64
# marital_status                  object
# loyalty_card                    object
# clv                            float64
# enrollment_type                 object
# enrollment_year                  int64
# enrollment_month                 int64
# cancellation_year                int64
# cancellation_month               int64
# dtype: object

# %%
df.head()
# Out:
#    loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    total_flights  distance  points_accumulated  points_redeemed  \
# 0              3      1521                 152                0
# 1             14      2030                 203                0
# 2              6      1200                 120                0
# 3              0         0                   0                0
# 4              0         0                   0                0
#
#    dollar_cost_points_redeemed          province          city postal_code  \
# 0                            0           alberta      edmonton     t9g 1w3
# 1                            0           ontario       toronto     m1r 4k3
# 2                            0  british columbia  dawson creek     u5i 4f1
# 3                            0  british columbia     vancouver     v5r 1w3
# 4                            0           ontario       toronto     p1l 8x8
#
#    gender education  salary marital_status loyalty_card      clv  \
# 0  female  bachelor   92552        married       aurora  7919.20
# 1    male   college   71800         single         nova  2887.74
# 2  female   college   71800       divorced         nova  2838.07
# 3    male  bachelor   63253        married         star  4170.57
# 4  female  bachelor   91163       divorced         star  6622.05
#
#   enrollment_type  enrollment_year  enrollment_month  cancellation_year  \
# 0        standard             2016                 8                  0
# 1        standard             2013                 3                  0
# 2        standard             2016                 7                  0
# 3        standard             2015                 8                  0
# 4        standard             2014                 1                  0
#
#    cancellation_month
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
#Hacemos csv con la fase de limpiza lista

df.to_csv('data/datos_final.csv')

# %% [markdown]
# # Fase 1: Exploración y Limpieza
#
# ## 1. Exploración Inicial
#
# ### Carga de Datos
#
# Se cargan los datos desde archivos CSV utilizando `pd.read_csv`. El primer DataFrame (`df1`) contiene la actividad de vuelos de clientes, y el segundo DataFrame (`df2`) contiene el historial de lealtad de clientes.
#
# ### Exploración del Primer DataFrame
#
# Se explora el contenido de `df1` de las siguientes maneras:
# - **Primeras 3 filas:** Muestra un vistazo inicial de los datos.
# - **Últimas 3 filas:** Permite ver los datos más recientes.
# - **3 filas aleatorias:** Ofrece una muestra representativa del DataFrame.
#
# ### Función de Exploración de Datos
#
# Se define una función para proporcionar una visión detallada del DataFrame, que incluye:
# - Información general sobre el número de filas y columnas.
# - Estadísticas descriptivas de las columnas.
# - Lista de columnas y detección de filas duplicadas.
# - Información sobre valores nulos y tipos de datos.
#
# ### Aplicación de la Función
#
# Se aplica la función de exploración a `df1` para obtener un resumen completo del DataFrame.
#
#
# ### Exploración del Segundo DataFrame
#
# De manera similar a `df1`, se examina el contenido de `df2`:
# - **Primeras 3 filas:** Muestra un vistazo inicial.
# - **Últimas 3 filas:** Muestra los datos más recientes.
# - **3 filas aleatorias:** Proporciona una muestra representativa.
#
# ### Función de Exploración para Columnas Categóricas
#
# Se crea un DataFrame con columnas de tipo objeto y se analizan los valores únicos y sus frecuencias para cada columna categórica.
#
# ### Unión de DataFrames
#
# Se unen `df1` y `df2` usando la columna 'Loyalty Number' como índice en `df2`. Se verifica el resultado con una muestra del DataFrame unido.
#
# ### Guardado del DataFrame Unido
#
# Se guarda el DataFrame unido en un archivo CSV para referencia futura.
#
# ## 2. Limpieza de Datos
#
# ### Relectura del CSV Unido
#
# Se lee el archivo CSV con los datos unidos para proceder con la limpieza.
#
# ### Comprobación de Duplicados y Valores Aleatorios
#
# Se verifica y se eliminan duplicados. Se revisa un valor específico para asegurarse de que no haya duplicados.
#
# ### Eliminación de Columnas Irrelevantes
#
# Se eliminan columnas innecesarias ('Unnamed: 0' y 'Country') que no aportan información relevante.
#
# ### Normalización de Nombres de Columnas
#
# Se normalizan los nombres de las columnas convirtiéndolos a minúsculas y reemplazando los espacios por guiones bajos.
#
# ### Normalización de Valores Categóricos
#
# Se convierten los valores de las columnas categóricas a minúsculas y se eliminan los espacios en blanco al inicio y al final.
#
# ### Manejo de Valores Nulos
#
# Se tratan los valores nulos:
# - Se reemplazan los valores nulos en las columnas 'cancellation_year' y 'cancellation_month' con 0.
# - Se cambian los valores negativos en 'salary' a positivos.
#
# ### Imputación de Valores Faltantes en 'Salary'
#
# Se imputan valores faltantes en 'salary' para la categoría 'college' usando la media calculada de las categorías más cercanas.
#
# ### Guardado del DataFrame Limpio
#
# Se guarda el DataFrame limpio en un archivo CSV para su uso en análisis futuros.
