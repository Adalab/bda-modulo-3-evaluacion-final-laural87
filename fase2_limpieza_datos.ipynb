# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import chi2_contingency, ttest_ind

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
# Leemos el csv con la unión que hemos creado en la fase anterior

df = pd.read_csv('data/data_join.csv', index_col= 0)

# %%
df.head(1)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
#
#    Dollar Cost Points Redeemed Country Province      City Postal Code  Gender  \
# 0                            0  Canada  Alberta  Edmonton     T9G 1W3  Female
#
#   Education   Salary Marital Status Loyalty Card     CLV Enrollment Type  \
# 0  Bachelor  92552.0        Married       Aurora  7919.2        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 8                NaN                 NaN

# %%
# Ya habíamos comprobado en la fase anterior, sabemos que tenemos duplicados

print(f'El numero de duplidados de este data frame es {df.duplicated().sum()}')
# Out:
# El numero de duplidados de este data frame es 1864

# %%
# compruebo la columa Loyality Number para ver si tiene duplicados

print(f'El numero de duplidados de este data frame es {df["Loyalty Number"].duplicated().sum()}') 
 

# Compruebo un valor aleatorio de esta columna

df[df["Loyalty Number"] == 100018].head(6)
# Out:
# El numero de duplidados de este data frame es 388887
#        Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0              100018  2017      1               3                        0
# 16901          100018  2017      2               2                        2
# 46353          100018  2018     10               6                        4
# 50703          100018  2017      4               4                        0
# 67604          100018  2017      5               0                        0
# 84505          100018  2017      6               4                        1
#
#        Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0                  3      1521               152.0                0
# 16901              4      1320               132.0                0
# 46353             10      3110               311.0              385
# 50703              4       924                92.0                0
# 67604              0         0                 0.0                0
# 84505              5      4330               433.0                0
#
#        Dollar Cost Points Redeemed Country Province      City Postal Code  \
# 0                                0  Canada  Alberta  Edmonton     T9G 1W3
# 16901                            0  Canada  Alberta  Edmonton     T9G 1W3
# 46353                           31  Canada  Alberta  Edmonton     T9G 1W3
# 50703                            0  Canada  Alberta  Edmonton     T9G 1W3
# 67604                            0  Canada  Alberta  Edmonton     T9G 1W3
# 84505                            0  Canada  Alberta  Edmonton     T9G 1W3
#
#        Gender Education   Salary Marital Status Loyalty Card     CLV  \
# 0      Female  Bachelor  92552.0        Married       Aurora  7919.2
# 16901  Female  Bachelor  92552.0        Married       Aurora  7919.2
# 46353  Female  Bachelor  92552.0        Married       Aurora  7919.2
# 50703  Female  Bachelor  92552.0        Married       Aurora  7919.2
# 67604  Female  Bachelor  92552.0        Married       Aurora  7919.2
# 84505  Female  Bachelor  92552.0        Married       Aurora  7919.2
#
#       Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 0            Standard             2016                 8                NaN
# 16901        Standard             2016                 8                NaN
# 46353        Standard             2016                 8                NaN
# 50703        Standard             2016                 8                NaN
# 67604        Standard             2016                 8                NaN
# 84505        Standard             2016                 8                NaN
#
#        Cancellation Month
# 0                     NaN
# 16901                 NaN
# 46353                 NaN
# 50703                 NaN
# 67604                 NaN
# 84505                 NaN

# %%
# Veo que la información es un historíco por mes y año de los vuelos tomados. Por lo tanto no tendría sentido tener duplicados

df.drop_duplicates(inplace=True)

#comprobamos que no tenemos duplicados
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Vamos a unificar el formato de las columnas, las queremos en minúscula y que el espacio sea una barra baja

# %%
#hacemos una variable de nuevas columnas que hará que las columnas aparezcan en miinuscula y que remplace el espacio por comas
new_columns = {column : column.lower().replace(' ', '_') for column in df}


#renombramos las columnas antiguas por las nuevas
df.rename(columns = new_columns, inplace= True)


# comprobamos que se ha realizado
df.sample(10)
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 67137           973846  2017      4               0                        0
# 4527            343001  2017      1               0                        0
# 30392           817527  2017      2               0                        0
# 182341          807256  2017     11               5                        4
# 107188          410552  2017      7               5                        0
# 138977          301794  2017      9              11                        3
# 210104          488679  2018      1               3                        0
# 100975          975531  2017      6               0                        0
# 280916          659400  2018      5               0                        0
# 64396           828643  2017      4               0                        0
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 67137               0         0                 0.0                0
# 4527                0         0                 0.0                0
# 30392               0         0                 0.0                0
# 182341              9      1197               119.0                0
# 107188              5      1330               133.0                0
# 138977             14      2436               243.0                0
# 210104              3      1515               151.0                0
# 100975              0         0                 0.0                0
# 280916              0         0                 0.0                0
# 64396               0         0                 0.0                0
#
#         dollar_cost_points_redeemed country          province          city  \
# 67137                             0  Canada  British Columbia       Kelowna
# 4527                              0  Canada       Nova Scotia       Halifax
# 30392                             0  Canada           Ontario       Toronto
# 182341                            0  Canada       Nova Scotia       Halifax
# 107188                            0  Canada  British Columbia     Vancouver
# 138977                            0  Canada  British Columbia  Dawson Creek
# 210104                            0  Canada           Ontario       Toronto
# 100975                            0  Canada          Manitoba      Winnipeg
# 280916                            0  Canada       Nova Scotia       Halifax
# 64396                             0  Canada  British Columbia     Vancouver
#
#        postal_code  gender education   salary marital_status loyalty_card  \
# 67137      V09 2E9    Male  Bachelor  47116.0         Single         Nova
# 4527       B3J 9S2  Female   College      NaN        Married       Aurora
# 30392      M2Z 4K1    Male  Bachelor  83172.0        Married       Aurora
# 182341     B3J 9S2  Female   College      NaN        Married         Star
# 107188     V1E 4R6  Female  Bachelor  70532.0        Married         Star
# 138977     U5I 4F1    Male   College      NaN         Single         Star
# 210104     M8Y 4K8    Male  Bachelor  48629.0        Married         Star
# 100975     R6Y 4T5    Male   College      NaN         Single         Star
# 280916     B3C 2M8    Male  Bachelor  72769.0        Married         Star
# 64396      V1E 4R6    Male   College      NaN        Married         Nova
#
#              clv enrollment_type  enrollment_year  enrollment_month  \
# 67137   16172.94  2018 Promotion             2018                 2
# 4527     5310.86        Standard             2016                 3
# 30392    7782.13        Standard             2015                 3
# 182341   2585.44        Standard             2012                 7
# 107188   2452.74        Standard             2016                 4
# 138977   4620.39        Standard             2012                 5
# 210104   3362.41        Standard             2016                 4
# 100975   1898.01        Standard             2018                11
# 280916   8679.80        Standard             2012                11
# 64396   11490.34        Standard             2017                 4
#
#         cancellation_year  cancellation_month
# 67137                 NaN                 NaN
# 4527                  NaN                 NaN
# 30392                 NaN                 NaN
# 182341                NaN                 NaN
# 107188                NaN                 NaN
# 138977                NaN                 NaN
# 210104                NaN                 NaN
# 100975                NaN                 NaN
# 280916                NaN                 NaN
# 64396                 NaN                 NaN

# %%
#Creamos una función para convertir en lower minúscula y le quitamos los espacios de delante y 


def modificar_lower_strip (lista_columnas):
    for columna in columnas_ojeto:
        df[columna] = df[columna].str.strip().str.lower()


# llamamos a la función
columnas_ojeto = df.select_dtypes(include = "object").columns
modificar_lower_strip(columnas_ojeto)
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0               100018  2017      1               3                        0
# 1               100102  2017      1              10                        4
# 2               100140  2017      1               6                        0
# 3               100214  2017      1               0                        0
# 4               100272  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 0                   3      1521               152.0                0
# 1                  14      2030               203.0                0
# 2                   6      1200               120.0                0
# 3                   0         0                 0.0                0
# 4                   0         0                 0.0                0
# ...               ...       ...                 ...              ...
# 405619              0         0                 0.0                0
# 405620              0         0                 0.0                0
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         dollar_cost_points_redeemed country          province          city  \
# 0                                 0  canada           alberta      edmonton
# 1                                 0  canada           ontario       toronto
# 2                                 0  canada  british columbia  dawson creek
# 3                                 0  canada  british columbia     vancouver
# 4                                 0  canada           ontario       toronto
# ...                             ...     ...               ...           ...
# 405619                            0  canada           ontario       toronto
# 405620                            0  canada      newfoundland    st. john's
# 405621                            0  canada            quebec   quebec city
# 405622                            0  canada  british columbia      victoria
# 405623                            0  canada           ontario        ottawa
#
#        postal_code  gender education    salary marital_status loyalty_card  \
# 0          t9g 1w3  female  bachelor   92552.0        married       aurora
# 1          m1r 4k3    male   college       NaN         single         nova
# 2          u5i 4f1  female   college       NaN       divorced         nova
# 3          v5r 1w3    male  bachelor   63253.0        married         star
# 4          p1l 8x8  female  bachelor   91163.0       divorced         star
# ...            ...     ...       ...       ...            ...          ...
# 405619     m1r 4k3    male   college       NaN        married       aurora
# 405620     a1c 6h9    male    doctor  217943.0         single         nova
# 405621     g1b 3l5  female  bachelor   47670.0        married         nova
# 405622     v10 6t5    male   college       NaN        married         star
# 405623     k1f 2r2  female  bachelor   46594.0        married         nova
#
#              clv enrollment_type  enrollment_year  enrollment_month  \
# 0        7919.20        standard             2016                 8
# 1        2887.74        standard             2013                 3
# 2        2838.07        standard             2016                 7
# 3        4170.57        standard             2015                 8
# 4        6622.05        standard             2014                 1
# ...          ...             ...              ...               ...
# 405619   7290.07        standard             2014                 5
# 405620   8564.77        standard             2012                 8
# 405621  20266.50        standard             2017                 7
# 405622   2631.56        standard             2018                 7
# 405623   8257.01  2018 promotion             2018                 2
#
#         cancellation_year  cancellation_month
# 0                     NaN                 NaN
# 1                     NaN                 NaN
# 2                     NaN                 NaN
# 3                     NaN                 NaN
# 4                     NaN                 NaN
# ...                   ...                 ...
# 405619                NaN                 NaN
# 405620                NaN                 NaN
# 405621                NaN                 NaN
# 405622                NaN                 NaN
# 405623                NaN                 NaN
#
# [403760 rows x 25 columns]

# %%
#comprobamos valores nulos 

df.isnull().sum()

#unicamente tenmos  3 columnas coon valores nulos
# entendemos las columnas que contienen información de cancelación es porque no ha cancelado por lo tanto pondremos los calores nan en 0 como una nueva categoria especial
# Out:
# loyalty_number                      0
# year                                0
# month                               0
# flights_booked                      0
# flights_with_companions             0
# total_flights                       0
# distance                            0
# points_accumulated                  0
# points_redeemed                     0
# dollar_cost_points_redeemed         0
# country                             0
# province                            0
# city                                0
# postal_code                         0
# gender                              0
# education                           0
# salary                         102260
# marital_status                      0
# loyalty_card                        0
# clv                                 0
# enrollment_type                     0
# enrollment_year                     0
# enrollment_month                    0
# cancellation_year              354110
# cancellation_month             354110
# dtype: int64

# %%
df['salary'].unique()
# Out:
# array([92552.,    nan, 63253., ..., 23160., 97206., 56345.])
